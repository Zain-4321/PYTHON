# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# Part A – Descriptive Statistics

# 1. Load the dataset
df = pd.read_csv('passenger_data.csv')  # Make sure this file is in the same directory

# 2. Calculate descriptive statistics
print("Mean:\n", df.mean(numeric_only=True))
print("\nMedian:\n", df.median(numeric_only=True))
print("\nMode:\n", df.mode(numeric_only=True).iloc[0])
print("\nVariance:\n", df.var(numeric_only=True))
print("\nStandard Deviation:\n", df.std(numeric_only=True))
print("\nSkewness:\n", df.skew(numeric_only=True))
print("\nKurtosis:\n", df.kurtosis(numeric_only=True))
# Out:
# Mean:
#  age                40.00
# ticket_price    14735.02
# dtype: float64
#
# Median:
#  age                39.5
# ticket_price    14388.5
# dtype: float64
#
# Mode:
#  age                24.0
# ticket_price    10121.0
# Name: 0, dtype: float64
#
# Variance:
#  age             1.268571e+02
# ticket_price    7.699445e+06
# dtype: float64
#
# Standard Deviation:
#  age               11.263088
# ticket_price    2774.787445
# dtype: float64
#
# Skewness:
#  age             0.006785
# ticket_price    0.299296
# dtype: float64
#
# Kurtosis:
#  age            -0.965379
# ticket_price   -0.963786
# dtype: float64

# %%
print(df.describe())
# Out:
#              age  ticket_price
# count  50.000000     50.000000
# mean   40.000000  14735.020000
# std    11.263088   2774.787445
# min    19.000000  10121.000000
# 25%    32.250000  12457.250000
# 50%    39.500000  14388.500000
# 75%    48.750000  16686.750000
# max    59.000000  19950.000000

# %%
sns.histplot(data=df, x='age')
plt.title("Histogram of Age")
plt.show()

# %%
sns.boxplot(data=df, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
print("\nCorrelation Matrix:\n", df.corr(numeric_only=True))
# Out:
# Correlation Matrix:
#                     age  ticket_price
# age           1.000000     -0.110453
# ticket_price -0.110453      1.000000

# %%
# 2. T-test example: Compare Age of males and females
# Make sure 'Sex' and 'Age' exist in your dataset
male_age = df[df['gender'] == 'M']['age'].dropna()
female_age = df[df['gender'] == 'F']['age'].dropna()

t_stat, p_val = ttest_ind(male_age, female_age, equal_var=False)
print(f"\nT-test (Age: Male vs Female):\nT-statistic = {t_stat}, P-value = {p_val}")
# Out:
# T-test (Age: Male vs Female):
# T-statistic = -0.46993597253217184, P-value = 0.6408080832543783
